# %%
import pandas as pd

# %%
waterdata = pd.read_csv("C:\\Users\\G3\\Downloads\\BKB_WaterQualityData_2020084.csv")

# %%
waterdata.head()
# Out:
#   Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN  01-03-1994             1.3                     11.7
# 1     Bay     NaN   1/31/1994             1.5                     12.0
# 2     Bay     NaN  02-07-1994             1.0                     10.5
# 3     Bay     NaN   2/23/1994             1.0                     10.1
# 4     Bay     NaN   2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
waterdata.isnull().sum()
# Out:
# Site_Id                       1
# Unit_Id                    2339
# Read_Date                     5
# Salinity (ppt)              130
# Dissolved Oxygen (mg/L)     851
# pH (standard units)          95
# Secchi Depth (m)             73
# Water Depth (m)              71
# Water Temp (?C)             121
# Air Temp-Celsius           2286
# Air Temp (?F)                71
# Time (24:00)                 63
# Field_Tech                   39
# DateVerified               1918
# WhoVerified                1918
# AirTemp (C)                   0
# Year                          0
# dtype: int64

# %%
data1 = waterdata

# %%
data1.head()
# Out:
#   Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN  01-03-1994             1.3                     11.7
# 1     Bay     NaN   1/31/1994             1.5                     12.0
# 2     Bay     NaN  02-07-1994             1.0                     10.5
# 3     Bay     NaN   2/23/1994             1.0                     10.1
# 4     Bay     NaN   2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
cleaned_data = data1.dropna().reset_index(drop=True)

# %%
cleaned_data.tail()
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay   01CSV 2014-06-10             0.0                      5.4
# 1       A   01CSV 2014-06-10             0.0                      0.0
# 2       B   01CSV 2014-06-10             0.0                      0.0
# 3       C   01CSV 2014-06-10             0.0                      4.3
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.0               0.4              0.8             15.0
# 1                  7.0               0.5              0.7             27.0
# 2                  8.0               0.3              0.3             27.0
# 3                  7.0               0.8              1.3             27.0
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# 0              22.0           72.0        09:45    Sue Poe    6/16/2014
# 1              23.0           74.0        11:00    Sue Poe    6/23/2014
# ...

# %%
duplicate_rows = cleaned_data[cleaned_data.duplicated()]

# %%
duplicate_rows.head()
# Out:
# Empty DataFrame
# Columns: [Site_Id, Unit_Id, Read_Date, Salinity (ppt), Dissolved Oxygen (mg/L), pH (standard units), Secchi Depth (m), Water Depth (m), Water Temp (?C), Air Temp-Celsius, Air Temp (?F), Time (24:00), Field_Tech, DateVerified, WhoVerified, AirTemp (C), Year]
# Index: []

# %%
cleaned_data.head()
# Out:
#   Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay   01CSV  06-10-2014             0.0                      5.4
# 1       A   01CSV  06-10-2014             0.0                      0.0
# 2       B   01CSV  06-10-2014             0.0                      0.0
# 3       C   01CSV  06-10-2014             0.0                      4.3
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.0               0.4              0.8             15.0
# 1                  7.0               0.5              0.7             27.0
# 2                  8.0               0.3              0.3             27.0
# 3                  7.0               0.8              1.3             27.0
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# 0              22.0           72.0        09:45    Sue Poe    6/16/2014
# 1              23.0           74.0        11:00    Sue Poe    6/23/2014
# ...

# %%
cleaned_data.dtypes
# Out:
# Site_Id                     object
# Unit_Id                     object
# Read_Date                   object
# Salinity (ppt)             float64
# Dissolved Oxygen (mg/L)    float64
# pH (standard units)        float64
# Secchi Depth (m)           float64
# Water Depth (m)            float64
# Water Temp (?C)            float64
# Air Temp-Celsius           float64
# Air Temp (?F)              float64
# Time (24:00)                object
# Field_Tech                  object
# DateVerified                object
# WhoVerified                 object
# AirTemp (C)                float64
# Year                         int64
# dtype: object

# %%
cleaned_data['Read_Date'] = pd.to_datetime(cleaned_data['Read_Date'])

# %%
cleaned_data
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay   01CSV 2014-06-10             0.0                      5.4
# 1       A   01CSV 2014-06-10             0.0                      0.0
# 2       B   01CSV 2014-06-10             0.0                      0.0
# 3       C   01CSV 2014-06-10             0.0                      4.3
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.0               0.4              0.8             15.0
# 1                  7.0               0.5              0.7             27.0
# 2                  8.0               0.3              0.3             27.0
# 3                  7.0               0.8              1.3             27.0
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# 0              22.0           72.0        09:45    Sue Poe    6/16/2014
# 1              23.0           74.0        11:00    Sue Poe    6/23/2014
# ...

# %%
data1.to_csv('C:\\Users\\G3\\Downloads\\waterdata.csv')
